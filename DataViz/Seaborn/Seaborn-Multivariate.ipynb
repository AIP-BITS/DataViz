# %%
# %cd /content/drive/MyDrive/Notebook/
# Out:
# /content/drive/MyDrive/Notebook

# %%
# %ls
# Out:
# Archive/  data/  Untitled0.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline

# %%
# %ls data/spo*
# Out:
# data/spotify.csv

# %%
spotify_data = pd.read_csv("data/spotify.csv")

# %%
spotify_data.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
spotify_data = pd.read_csv("data/spotify.csv",index_col="Date",parse_dates=True)
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2017-01-06 to 2018-01-09
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Shape of You              366 non-null    int64
#  1   Despacito                 359 non-null    float64
#  2   Something Just Like This  319 non-null    float64
#  3   HUMBLE.                   282 non-null    float64
#  4   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 17.2 KB

# %%
spotify_data.shape
# Out:
# (366, 5)

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify_data)

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify_data['Shape of You'],label="Shape of You")
sns.lineplot(data=spotify_data['Despacito'],label="Despacito")
plt.ylabel("Count")
plt.show()

# %%
# %ls data/mus*
# Out:
# data/museum_visitors.csv

# %%
musem = pd.read_csv("data/museum_visitors.csv")
musem.head()
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 0  2014-01-01        24778              4486                     1581
# 1  2014-02-01        18976              4172                     1785
# 2  2014-03-01        25231              7082                     3229
# 3  2014-04-01        26989              6756                     2129
# 4  2014-05-01        36883             10858                     3676
#
#    America Tropical Interpretive Center
# 0                                  6602
# 1                                  5029
# 2                                  8129
# 3                                  2824
# 4                                 10694

# %%
musem = pd.read_csv("data/museum_visitors.csv",index_col="Date",parse_dates=True)
musem.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=musem)

# %%
# %ls data/fli*
# Out:
# data/flight_delays.csv

# %%
flight = pd.read_csv("data/flight_delays.csv")
flight.head()
# Out:
#    Month        AA        AS         B6        DL         EV         F9  \
# 0      1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1      2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 2      3  6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 3      4  4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 4      5  5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#          HA         MQ         NK         OO        UA        US        VX  \
# 0  3.512640  18.164974  11.398054  10.889894  6.352729  3.107457  1.420702
# 1  6.029967  21.301627  16.474466   9.588895  7.260662  7.114455  7.784410
# 2  3.468383  11.018418  10.039118   3.181693  4.892212  3.330787  5.348207
# 3  0.011022   5.131228   8.766224   3.223796  4.376092  2.660290  0.995507
# 4  0.826426   5.466790  22.397347   4.141162  6.827695  0.681605  7.102021
#
#          WN
# 0  3.389466
# 1  3.501363
# 2  3.263341
# 3  2.996399
# 4  5.680777

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=flight.Month,y=flight.NK)
plt.ylabel("Arrival Delay (in minutues)")
# Out:
# Text(0, 0.5, 'Arrival Delay (in minutues)')

# %%
plt.figure(figsize=(10,6))
clrs = ['grey' if (x<18) else 'red' for x in flight.NK]
sns.barplot(x=flight.Month,y=flight.NK,palette=clrs)
plt.ylabel("Arrival Delay (in minutues)")
# Out:
# Text(0, 0.5, 'Arrival Delay (in minutues)')

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
data = np.array([[1,3,'weekday'],[2,2.5,'weekday'],
                 [3,2.7,'weekend'],[4,2.8,'weekend'],
                 [5,3,'weekday'],[6,3.1,'weekday'],
                 [7,3,'weekday'],[8,3.1,'weekday'],
                 [9,3.1,'weekday'],[10,3.1,'weekend'],
                 
                 
                 ])

# %%
df = pd.DataFrame(data,columns=['day','kms','day_cat'])
df.head()
# Out:
#   day  kms  day_cat
# 0   1    3  weekday
# 1   2  2.5  weekday
# 2   3  2.7  weekend
# 3   4  2.8  weekend
# 4   5    3  weekday

# %%
sns.set_palette(sns.color_palette("flare", as_cmap=False))

# %%
sns.scatterplot(data=df,x='day',y='kms',hue='day_cat')

# %%
# %reset -f

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
penguins.island.value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
penguins.sex.value_counts()
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.jointplot(data=penguins,x='flipper_length_mm',y='bill_length_mm',hue='species')

# %%
sns.pairplot(data=penguins,hue='species')

# %% [markdown]
# # Statistical Analysis

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue='smoker',style="smoker")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue='smoker',style="time")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue='size')

# %%
sns.relplot(x="total_bill",y="tip",data=tips,size='size')

# %%
sns.relplot(x="total_bill",y="tip",data=tips,size='size',sizes=(15,200))
